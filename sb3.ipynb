# %%
import gym

import stable_baselines3 as sb3
from stable_baselines3 import PPO, DQN
from stable_baselines3.dqn.policies import MlpPolicy
from stable_baselines3.common.env_checker import check_env
from gym.utils.env_checker import check_env as gym_check_env

from game import Game, GameOptions
from wrappers import *
import datetime

# %% [markdown]
# Example from sb3

# %%
env = gym.make("CartPole-v1")

model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render()
    # VecEnv resets automatically
    # if done:
    #   obs = env.reset()

env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.9     |
# |    ep_rew_mean     | 23.9     |
# | time/              |          |
# |    fps             | 6104     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.9         |
# |    ep_rew_mean          | 26.9         |
# | time/                   |              |
# |    fps                  | 4002         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0085681155 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.000135     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.31         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0184      |
# |    value_loss           | 58.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.1        |
# |    ep_rew_mean          | 34.1        |
# | time/                   |             |
# |    fps                  | 3648        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009568443 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.663      |
# |    explained_variance   | 0.0833      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 34.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.1        |
# |    ep_rew_mean          | 47.1        |
# | time/                   |             |
# |    fps                  | 3487        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007624748 |
# |    clip_fraction        | 0.0855      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0185     |
# |    value_loss           | 49.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.6        |
# |    ep_rew_mean          | 59.6        |
# | time/                   |             |
# |    fps                  | 3366        |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008302089 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.616      |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.8        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 56.5        |
# -----------------------------------------
# /Users/manuelbotija_macbookair/dev/pygame_test/.venv/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:207: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")

# %% [markdown]
# Tinkering with Game - first instantiate game

# %%
options = GameOptions()
options.max_steps = 300
options.max_projectiles_per_turret = 0
options.reward_type = 4


env = Game(render_mode=None, options=options)
gym_check_env(env)
settings = TorchWrapperSettings(normalize=True, flatten_action=True, skip_frames=None, to_tensor=False)
env = TorchWrapper(env, wrapper_settings = settings)
policy_kwargs = dict(   activation_fn=torch.nn.ReLU, 
                        net_arch=[128, 128], 
                        optimizer_class = torch.optim.AdamW, 
                        optimizer_kwargs = dict(amsgrad=True),
                        normalize_images=False)

gym_check_env(env)
check_env(env, warn=True)
# Out:
# /Users/manuelbotija_macbookair/dev/pygame_test/.venv/lib/python3.9/site-packages/gym/utils/env_checker.py:277: UserWarning: WARN: The environment (<TorchWrapper<FlattenObservation<Game instance>>>) is different from the unwrapped version (<Game instance>). This could effect the environment checker as the environment most likely has a wrapper applied to it. We recommend using the raw environment for `check_env` using `env.unwrapped`.
#   logger.warn(

# %%
MEM_SIZE = 10_000
BATCH_SIZE = 128
GAMMA = 0.95
EPS_START = 0.95
EPS_END = 0.05
EPS_DECAY = 4000 # The higher the longer it takes to decay
TAU = 0.005
LR = 1e-4

# %%
model = DQN("MlpPolicy", env, verbose=1, 
                    learning_rate=LR, 
                    buffer_size=MEM_SIZE, 
                    batch_size=BATCH_SIZE, 
                    gamma=GAMMA, 
                    tau=TAU, 
                    exploration_initial_eps=EPS_START, 
                    exploration_final_eps=EPS_END, 
                    train_freq=1,
                    learning_starts=BATCH_SIZE,
                    target_update_interval=1,
                    gradient_steps=-1,
                    policy_kwargs=policy_kwargs)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100_000, progress_bar=False)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -90.2    |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 935      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.24     |
# |    n_updates        | 1071     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | -34.6    |
# |    exploration_rate | 0.734    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 918      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2400     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17     |
# |    n_updates        | 2271     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 261      |
# |    ep_rew_mean      | 93.6     |
# |    exploration_rate | 0.668    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 907      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3133     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.57     |
# |    n_updates        | 3004     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 257      |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 895      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4112     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.7      |
# |    n_updates        | 3983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 243      |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.513    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 889      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4852     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.86     |
# |    n_updates        | 4723     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 252      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.405    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 887      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 6052     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.99     |
# |    n_updates        | 5923     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 255      |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.306    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 882      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7151     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.1      |
# |    n_updates        | 7022     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 235      |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.273    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 881      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7525     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.84     |
# |    n_updates        | 7396     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.211    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 879      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 8209     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.11     |
# |    n_updates        | 8080     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.152    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 876      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8863     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.05     |
# |    n_updates        | 8734     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | 188      |
# |    exploration_rate | 0.0533   |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 875      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 9963     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.4      |
# |    n_updates        | 9834     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 874      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10791    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.22     |
# |    n_updates        | 10662    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 229      |
# |    ep_rew_mean      | 188      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 873      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 11930    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3        |
# |    n_updates        | 11801    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 230      |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 872      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 12887    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.08     |
# |    n_updates        | 12758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 229      |
# |    ep_rew_mean      | 204      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 869      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 13767    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.79     |
# |    n_updates        | 13638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | 207      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 869      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14455    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.37     |
# |    n_updates        | 14326    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 206      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 868      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 15526    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.53     |
# |    n_updates        | 15397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 867      |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 16438    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.92     |
# |    n_updates        | 16309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | 188      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 866      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 17553    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.71     |
# |    n_updates        | 17424    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 184      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 866      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 18194    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.18     |
# |    n_updates        | 18065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 179      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 866      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 19103    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.92     |
# |    n_updates        | 18974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 865      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 20303    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.58     |
# |    n_updates        | 20174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 865      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 20958    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.96     |
# |    n_updates        | 20829    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 863      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 21814    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.09     |
# |    n_updates        | 21685    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 863      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 22394    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.09     |
# |    n_updates        | 22265    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 862      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 23125    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.01     |
# |    n_updates        | 22996    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 859      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 24045    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.47     |
# |    n_updates        | 23916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 858      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 24969    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.77     |
# |    n_updates        | 24840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 188      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 857      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 26169    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.73     |
# |    n_updates        | 26040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 857      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 26861    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.97     |
# |    n_updates        | 26732    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 856      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 27787    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.19     |
# |    n_updates        | 27658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 194      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 856      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 28786    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.07     |
# |    n_updates        | 28657    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 190      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 855      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 29623    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.89     |
# |    n_updates        | 29494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 855      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 30079    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.42     |
# |    n_updates        | 29950    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 188      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 855      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 31013    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.47     |
# |    n_updates        | 30884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 194      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 855      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 31800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.51     |
# |    n_updates        | 31671    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 854      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 32775    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.43     |
# |    n_updates        | 32646    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 213      |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 854      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 33210    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.02     |
# |    n_updates        | 33081    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 212      |
# |    ep_rew_mean      | 194      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 854      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 34122    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.46     |
# |    n_updates        | 33993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 210      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 854      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 34792    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.17     |
# |    n_updates        | 34663    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 212      |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 853      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 35702    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.93     |
# |    n_updates        | 35573    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 853      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 36902    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.21     |
# |    n_updates        | 36773    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 206      |
# |    ep_rew_mean      | 204      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 853      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 37045    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.44     |
# |    n_updates        | 36916    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 853      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 37729    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.88     |
# |    n_updates        | 37600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 852      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 38400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2        |
# |    n_updates        | 38271    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 852      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 39332    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.35     |
# |    n_updates        | 39203    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 852      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 39675    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.3      |
# |    n_updates        | 39546    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 852      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 40378    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.7      |
# |    n_updates        | 40249    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 852      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 40786    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.01     |
# |    n_updates        | 40657    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 851      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 41202    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.23     |
# |    n_updates        | 41073    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 851      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 42047    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.99     |
# |    n_updates        | 41918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 849      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 42990    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 42861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 848      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 44190    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.81     |
# |    n_updates        | 44061    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 849      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 44795    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.12     |
# |    n_updates        | 44666    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 849      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 45472    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.12     |
# |    n_updates        | 45343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 849      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 46405    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.69     |
# |    n_updates        | 46276    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 849      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 47040    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.77     |
# |    n_updates        | 46911    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 849      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 47989    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.99     |
# |    n_updates        | 47860    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 848      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 49189    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.66     |
# |    n_updates        | 49060    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 227      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 848      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 49919    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.78     |
# |    n_updates        | 49790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 848      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 50876    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.48     |
# |    n_updates        | 50747    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 848      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 51528    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17     |
# |    n_updates        | 51399    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 848      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 52204    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.88     |
# |    n_updates        | 52075    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 849      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 53238    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.69     |
# |    n_updates        | 53109    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 849      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 54438    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.31     |
# |    n_updates        | 54309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 849      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 55160    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.83     |
# |    n_updates        | 55031    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 849      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 56134    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.21     |
# |    n_updates        | 56005    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 211      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 849      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 56850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.81     |
# |    n_updates        | 56721    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 203      |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 849      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 58050    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62     |
# |    n_updates        | 57921    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 213      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 849      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 58445    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.3      |
# |    n_updates        | 58316    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 849      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 59217    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.44     |
# |    n_updates        | 59088    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 849      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 59872    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.73     |
# |    n_updates        | 59743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 849      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 60531    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.16     |
# |    n_updates        | 60402    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 849      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 60959    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.53     |
# |    n_updates        | 60830    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 848      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 61735    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.77     |
# |    n_updates        | 61606    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 847      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 62169    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.43     |
# |    n_updates        | 62040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 847      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 63183    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.18     |
# |    n_updates        | 63054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 230      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 847      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 64029    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.02     |
# |    n_updates        | 63900    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 847      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 64809    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 64680    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 847      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 65540    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.84     |
# |    n_updates        | 65411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 846      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 66420    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.63     |
# |    n_updates        | 66291    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 244      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 846      |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 66929    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.03     |
# |    n_updates        | 66800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 846      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 67854    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.89     |
# |    n_updates        | 67725    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 247      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 846      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 68565    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.49     |
# |    n_updates        | 68436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 245      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 846      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 69006    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.08     |
# |    n_updates        | 68877    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 847      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 69775    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.97     |
# |    n_updates        | 69646    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 248      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 847      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 70824    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.09     |
# |    n_updates        | 70695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 242      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 846      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 71762    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.79     |
# |    n_updates        | 71633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 244      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 846      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 72435    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.61     |
# |    n_updates        | 72306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 244      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 846      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 73440    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.66     |
# |    n_updates        | 73311    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 846      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 74640    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.83     |
# |    n_updates        | 74511    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 241      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# ...
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 846      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 77387    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.79     |
# |    n_updates        | 77258    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 846      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 77881    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62     |
# |    n_updates        | 77752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 846      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 78516    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 78387    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 226      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 846      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 79677    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.44     |
# |    n_updates        | 79548    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 846      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 80866    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65     |
# |    n_updates        | 80737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 846      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 80990    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.58     |
# |    n_updates        | 80861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 846      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 81852    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.32     |
# |    n_updates        | 81723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 845      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 83052    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.07     |
# |    n_updates        | 82923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 845      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 84144    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.52     |
# |    n_updates        | 84015    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 204      |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 845      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 85184    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 85055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 845      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 85690    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.91     |
# |    n_updates        | 85561    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 202      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 844      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 86552    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.41     |
# |    n_updates        | 86423    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | 190      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 843      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 87752    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.08     |
# |    n_updates        | 87623    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 206      |
# |    ep_rew_mean      | 201      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 843      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 88452    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48     |
# |    n_updates        | 88323    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 204      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 843      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 88966    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 88837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 209      |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 843      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 89920    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.24     |
# |    n_updates        | 89791    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 211      |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 842      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 90860    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19     |
# |    n_updates        | 90731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 841      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 91603    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.89     |
# |    n_updates        | 91474    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 206      |
# |    ep_rew_mean      | 204      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 841      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 92333    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.83     |
# |    n_updates        | 92204    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | 207      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 841      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 93215    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.73     |
# |    n_updates        | 93086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 207      |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 840      |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 94168    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.81     |
# |    n_updates        | 94039    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 204      |
# |    ep_rew_mean      | 217      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 839      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 95035    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.8      |
# |    n_updates        | 94906    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 204      |
# |    ep_rew_mean      | 217      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 838      |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 95983    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.44     |
# |    n_updates        | 95854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 220      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 838      |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 96439    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46     |
# |    n_updates        | 96310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 203      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 838      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 97507    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48     |
# |    n_updates        | 97378    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 206      |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 838      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 98010    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.64     |
# |    n_updates        | 97881    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 207      |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 839      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 98569    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.69     |
# |    n_updates        | 98440    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | 223      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 838      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 99317    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.53     |
# |    n_updates        | 99188    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 838      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 99757    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 99628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 243      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 839      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 99926    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2        |
# |    n_updates        | 99797    |
# ----------------------------------
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#save model with current date
model.save("sb3/dqn_{}".format(datetime.datetime.now().strftime("%Y%m%d-%H%M%S")))

# %% [markdown]
# ## Train with PPO

# %%
model = PPO("MlpPolicy", env, verbose=1,
                    learning_rate=LR, 
                    buffer_size=MEM_SIZE, 
                    batch_size=BATCH_SIZE, 
                    gamma=GAMMA, 
                    tau=TAU, 
                    exploration_initial_eps=EPS_START, 
                    exploration_final_eps=EPS_END, 
                    train_freq=1,
                    learning_starts=BATCH_SIZE,
                    target_update_interval=1,
                    gradient_steps=-1,
                    policy_kwargs=policy_kwargs)
model.learn(total_timesteps=100_000)
#save model with current date
model.save("sb3/ppo_{}".format(datetime.datetime.now().strftime("%Y%m%d-%H%M%S")))

# %% [markdown]
# # Play game with the model

# %%
env = Game(render_mode="human", options=options)
env = TorchWrapper(env, wrapper_settings = settings)
obs, _ = env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, _, info = env.step(action)
    env.render()
    # VecEnv resets automatically
    if done:
      obs, _ = env.reset()

env.close()
